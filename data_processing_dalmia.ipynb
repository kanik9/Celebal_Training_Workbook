# %%
import datetime
import pandas as pd
import mysql.connector 
import mysql.connector.errors

# %%
try:
    con = mysql.connector.connect(
                                        host='127.0.0.1',
                                        user='myuser',
                                        password='user',
                                        database='celebal'
                                        )
    
    
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print("Database does not exist")
    else:
        print(err)

# %%
def update(a):
    updated_columns = []
    for i in range(len(a)):
        if type(a[i]) == str:
            updated_columns.append(a[i])
        elif type(a[i]) == datetime.datetime:
            head_date = a[i].strftime("%b_%y")
            string = str(head_date)
            updated_columns.append(string)
        else :
            pass
    return updated_columns


def type_convert(data,columns):
    for i in range(len(columns)):
        if data[columns[i]].dtype == float:
            data[columns[i]] = data[columns[i]].astype(int)
        else:
            pass
    return data

# %%
def fc_file():
    data = pd.read_excel("./FC Model_RGP.xlsx",header=0)
    data = data.fillna(0)
    columns = list(data.columns)   
    new_columns = update(columns)
    data = type_convert(data,columns)
    data.columns = new_columns
    data = data
    data.to_csv("./FC_Model_RGP.csv")
    
def ncr_file():
    data = pd.read_excel("./NCR Inputs-East.xlsx")
    data = data.fillna(0)
    columns = list(data.columns)
    data = type_convert(data,columns)
    data = data
    data.to_csv("./NCR_Inputs_East.csv")

def vc_model_file():
    data = pd.ExcelFile("./VC Model_RGP.xlsx")
    sheet_name = ['2.Clk-Input','3.Cem-Input', '6.LS Cost', '7.Power Mix', '8.Slag' ,'9.Flyash', '9.1.Pond Ash', '10.Coal_Petcoke', '10.1.Coal_Petcoke Rate', '11.1.GF_RGP', '12.Stock']
    for name in sheet_name:
        if name == '2.Clk-Input':
            data_sheet = pd.read_excel(data,sheet_name=name,skiprows=8,index_col=False,header=1)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./2_Clk_Input.csv")
            
        elif name == '3.Cem-Input':
            data_sheet = pd.read_excel(data,sheet_name=name,skiprows=10,index_col=False,header=1)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./3_Cem_Input.csv")
        
        
        elif name == '6.LS Cost':
            data_sheet = pd.read_excel(data,sheet_name='6.LS Cost',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./6_LS_Cost.csv") 
            
            
        elif name == '7.Power Mix':
            data_sheet = pd.read_excel(data,sheet_name='7.Power Mix',skiprows=3,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./7_Power_Mix.csv") 
            
            
        elif name == '8.Slag':
            data_sheet = pd.read_excel(data,sheet_name='8.Slag',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./8_Slag.csv") 
            
            
        elif name == '9.Flyash':
            data_sheet = pd.read_excel(data,sheet_name='9.Flyash',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./9_Flyash.csv") 
            
            
        elif name == '9.1.Pond Ash':
            data_sheet = pd.read_excel(data,sheet_name='9.1.Pond Ash',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./9_1_Pond_Ash.csv") 
            
            
        elif name == '10.Coal_Petcoke':
            data_sheet = pd.read_excel(data,sheet_name='10.Coal_Petcoke',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./10_Coal_Petcoke.csv") 
            
            
        elif name == '10.1.Coal_Petcoke Rate':
            data_sheet = pd.read_excel(data,sheet_name='10.1.Coal_Petcoke Rate',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./10_1_Coal_Petcoke_Rate.csv") 
            
            
        elif name == '11.1.GF_RGP':
            data_sheet = pd.read_excel(data,sheet_name='11.1.GF_RGP',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./11_1_GF_RGP.csv") 
            
            
        elif name == '12.Stock':
            data_sheet = pd.read_excel(data,sheet_name='12.Stock',skiprows=2,index_col=False,header=0)
            data_sheet = data_sheet.fillna(0)
            columns = list(data_sheet.columns)
            new_columns = update(columns)
            data_sheet = type_convert(data_sheet,columns)
            data_sheet.columns = new_columns
            data_sheet = data_sheet
            data_sheet.to_csv("./12_Stock.csv") 
    print("Done")
            

vc_model_file()
# Out:
# Done

# %%
import mysql.connector
from mysql.connector import Error

# %%
def DataFrameToMysql(dataframe):
    try :
        conn = mysql.connector.connect(host='localhost', user='myuser', password='user', database='celebal',charset='utf8')
        cur = conn.cursor()

# %%
answer, con = check_database('FC_Model_RGP')
    cursor = con.cursor()
    if answer == True:
        query = """
                    LOAD DATA LOCAL INFILE "./FC_Model_RGP.csv" 
                    INTO table FC_Model_RGP
                    FIELDS TERMINATED BY ','
                    LINES TERMINATED BY '\n' 
                    (Cost_Heads,FY_20, FY_21, Apr_20, May_20, Jun_20, Jul_20, Aug_20, Sep_20, Oct_20, Nov_20, Dec_20, Jan_21, Feb_21, Mar_21)
                """
        try:
            cursor.execute(query)
        except mysql.connector.Error as err:
            print(err)
            sys.exit(1)
        cnx.close()
    
    elif answer == "1146 (42S02): Table '%s' doesn't exist"%FC_Model_RGP :
        query = """
                        CREATE TABLE FC_Model_RGP(
                        id INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
                        Cost_Heads VARCHAR(100),
                        FY_20 INT,
                        FY_21 INT,
                        Apr_20 INT,
                        May_20 INT,
                        Jun_20 INT, 
                        Jul_20 INT,
                        Aug_20 INT, 
                        Sep_20 INT,
                        Oct_20 INT,
                        Nov_20 INT,
                        Dec_20 INT,
                        Jan_21 INT, 
                        Feb_21 INT,
                        Mar_21 INT)
                """
        query_1 =  """
                    LOAD DATA LOCAL INFILE "./FC_Model_RGP.csv" 
                    INTO table FC_Model_RGP
                    FIELDS TERMINATED BY ','
                    LINES TERMINATED BY '\n' 
                    (Cost_Heads,FY_20, FY_21, Apr_20, May_20, Jun_20, Jul_20, Aug_20, Sep_20, Oct_20, Nov_20, Dec_20, Jan_21, Feb_21, Mar_21)
                """
        
        
        try:
            cursor.execute(query)
            cursor.execute(query_1)
            
        except con.Error as err:
            print(err)
            sys.exit(1)
        cnx.close()
